# %% [markdown]
# <a href="https://colab.research.google.com/github/ajh5120-eng/BTE-320/blob/main/In_Class_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for hours in range(1, 9, 1):
  fee = 5 + (2.5 * hours)
  if fee < 10.0:
    fee = 10.0
  elif fee > 20:
    fee = 20.0

  print(hours, fee)
# Out:
# 1 10.0
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20.0
# 8 20.0
