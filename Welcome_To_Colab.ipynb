# %% [markdown]
# <a href="https://colab.research.google.com/github/ajh5120-eng/BTE-320/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!
