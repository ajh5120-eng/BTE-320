# %% [markdown]
# <a href="https://colab.research.google.com/github/ajh5120-eng/BTE-320/blob/main/In_Class_Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
products = {
    "P-01": 9.95,
    "P-02": 10.5
}

id = input("Enter product ID: ")

if id in products
  print (products[id])
else:
  print(f"Product {id} not found...")

# %%
products = {
    "P-01": 9.95,
    "P-02": 10.5
}

id = input("Enter product ID: ")

print(products.get(id, f"Product {id} not found...")
