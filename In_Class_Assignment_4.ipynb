# %% [markdown]
# <a href="https://colab.research.google.com/github/ajh5120-eng/BTE-320/blob/main/In_Class_Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

ticket = 10
init_attendance = 20
fixed_cost = 200

for ad in range (0, 201, 25):
  revenue = (init_attendance + 2 * round(math.sqrt(ad))) * 10
  costs = fixed_cost + ad
  profit = revenue - costs
  print(ad, profit)
# Out:
# 0 0
# 25 75
# 50 90
# 75 105
# 100 100
# 125 95
# 150 90
# 175 85
# 200 80
