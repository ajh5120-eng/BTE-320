# %% [markdown]
# <a href="https://colab.research.google.com/github/ajh5120-eng/BTE-320/blob/main/Class_3_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
operator = input("Choose numerical operator: ")

if operator == '+':
  result = num1 + num2
elif operator == '-':
  result = num1 - num2
elif operator == '*':
  result = num1 * num2
elif operator == '/':
  result = num1 / num2
elif operator == '//':
  result = num1 // num2
elif operator == '**':
  result = num1 ** num2
elif operator == '%':
  result = num1 % num2
else:
  print("Invalid operation")
  result = None

print(f"Result: {res}")
